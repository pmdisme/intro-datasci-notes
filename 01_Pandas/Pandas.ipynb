# %%
import pandas as pd

# %%
df = pd.read_csv('players.csv')
df
# Out:
#            surname     team    position  minutes  shots  passes  tackles  \
# 0           Abdoun  Algeria  midfielder       16      0       6        0
# 1          Belhadj  Algeria    defender      270      1     146        8
# 2        Boudebouz  Algeria  midfielder       74      3      28        1
# 3        Bougherra  Algeria    defender      270      1      89       11
# 4         Chaouchi  Algeria  goalkeeper       90      0      17        0
# ..             ...      ...         ...      ...    ...     ...      ...
# 590         Holden      USA  midfielder        4      0       2        0
# 591         Howard      USA  goalkeeper      390      0      81        0
# 592  Jozy Altidore      USA     forward      356      8      84        2
# 593         Onyewu      USA    defender      170      1      69        2
# 594         Torres      USA  midfielder       45      1      32        0
#
#      saves  Unnamed: 8  Unnamed: 9  ...  Unnamed: 16  Unnamed: 17  \
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['surname', 'team', 'position', 'minutes', 'shots', 'passes', 'tackles',
#        'saves', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11',
#        'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=595, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 595 entries, 0 to 594
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   surname      595 non-null    object
#  1   team         595 non-null    object
#  2   position     595 non-null    object
#  3   minutes      595 non-null    int64
#  4   shots        595 non-null    int64
#  5   passes       595 non-null    int64
#  6   tackles      595 non-null    int64
#  7   saves        595 non-null    int64
#  8   Unnamed: 8   0 non-null      float64
#  9   Unnamed: 9   0 non-null      float64
#  10  Unnamed: 10  0 non-null      float64
#  11  Unnamed: 11  0 non-null      float64
#  12  Unnamed: 12  0 non-null      float64
#  13  Unnamed: 13  0 non-null      float64
#  14  Unnamed: 14  0 non-null      float64
#  15  Unnamed: 15  0 non-null      float64
#  16  Unnamed: 16  0 non-null      float64
#  17  Unnamed: 17  0 non-null      float64
# ...

# %%
df = df.set_index('surname')
df
# Out:
#                   team    position  minutes  shots  passes  tackles  saves  \
# surname
# Abdoun         Algeria  midfielder       16      0       6        0      0
# Belhadj        Algeria    defender      270      1     146        8      0
# Boudebouz      Algeria  midfielder       74      3      28        1      0
# Bougherra      Algeria    defender      270      1      89       11      0
# Chaouchi       Algeria  goalkeeper       90      0      17        0      2
# ...                ...         ...      ...    ...     ...      ...    ...
# Holden             USA  midfielder        4      0       2        0      0
# Howard             USA  goalkeeper      390      0      81        0     14
# Jozy Altidore      USA     forward      356      8      84        2      0
# Onyewu             USA    defender      170      1      69        2      0
# Torres             USA  midfielder       45      1      32        0      0
#
# ...

# %% [markdown]
# # Selection

# %%
df.loc['Holden', 'position']
# [row, column]
# Out:
# 'midfielder'

# %%
df.loc[['Messi','Ronaldo'],['team','passes','shots']]
# Out:
#               team  passes  shots
# surname
# Messi    Argentina     321     21
# Ronaldo   Portugal      91     18

# %%
df.loc['Holden':'Onyewu','position':'passes']
# Out:
#                  position  minutes  shots  passes
# surname
# Holden         midfielder        4      0       2
# Howard         goalkeeper      390      0      81
# Jozy Altidore     forward      356      8      84
# Onyewu           defender      170      1      69

# %%
df.loc[['Messi','Ronaldo'] , :'shots']
# Out:
#               team position  minutes  shots
# surname
# Messi    Argentina  forward      450     21
# Ronaldo   Portugal  forward      360     18

# %%
df.loc['Torres', : ]
# Out:
#              team    position  minutes  shots  passes  tackles  saves  \
# surname
# Torres   Paraguay    defender       82      2      29        1      0
# Torres      Spain     forward      278      9      50        0      0
# Torres        USA  midfielder       45      1      32        0      0
#
#          Unnamed: 8  Unnamed: 9  Unnamed: 10  ...  Unnamed: 16  Unnamed: 17  \
# surname                                       ...
# Torres          NaN         NaN          NaN  ...          NaN          NaN
# Torres          NaN         NaN          NaN  ...          NaN          NaN
# Torres          NaN         NaN          NaN  ...          NaN          NaN
#
#          Unnamed: 18  Unnamed: 19  Unnamed: 20  Unnamed: 21  Unnamed: 22  \
# surname
# Torres           NaN          NaN          NaN          NaN          NaN
# Torres           NaN          NaN          NaN          NaN          NaN
# Torres           NaN          NaN          NaN          NaN          NaN
#
# ...

# %%
s = df.loc['Messi', : ]
s
# Out:
# team           Argentina
# position         forward
# minutes              450
# shots                 21
# passes               321
# tackles               10
# saves                  0
# Unnamed: 8           NaN
# Unnamed: 9           NaN
# Unnamed: 10          NaN
# Unnamed: 11          NaN
# Unnamed: 12          NaN
# Unnamed: 13          NaN
# Unnamed: 14          NaN
# Unnamed: 15          NaN
# Unnamed: 16          NaN
# Unnamed: 17          NaN
# Unnamed: 18          NaN
# Unnamed: 19          NaN
# Unnamed: 20          NaN
# Unnamed: 21          NaN
# Unnamed: 22          NaN
# Unnamed: 23          NaN
# Unnamed: 24          NaN
# Unnamed: 25          NaN
# Name: Messi, dtype: object

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s.to_frame().T
# transpost
# Out:
#             team position minutes shots passes tackles saves Unnamed: 8  \
# Messi  Argentina  forward     450    21    321      10     0        NaN
#
#       Unnamed: 9 Unnamed: 10  ... Unnamed: 16 Unnamed: 17 Unnamed: 18  \
# Messi        NaN         NaN  ...         NaN         NaN         NaN
#
#       Unnamed: 19 Unnamed: 20 Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24  \
# Messi         NaN         NaN         NaN         NaN         NaN         NaN
#
#       Unnamed: 25
# Messi         NaN
#
# [1 rows x 25 columns]

# %%
df.iloc[0,2]
# Out:
# 16

# %%
df.iloc[[56,34,78,100], [0,4,1,5]]
# Out:
#                    team  passes    position  tackles
# surname
# Wilkshire     Australia     117  midfielder        8
# Romero        Argentina      47  goalkeeper        0
# Assou-Ekotto   Cameroon     116    defender        5
# Estrada           Chile      16  midfielder        2

# %%
df.iloc[0:4, 1:5]
# row 0-3, column 1-4
# Out:
#              position  minutes  shots  passes
# surname
# Abdoun     midfielder       16      0       6
# Belhadj      defender      270      1     146
# Boudebouz  midfielder       74      3      28
# Bougherra    defender      270      1      89

# %%
df.shots # shortcut using
# or df['shots']
# Out:
# surname
# Abdoun           0
# Belhadj          1
# Boudebouz        3
# Bougherra        1
# Chaouchi         0
#                 ..
# Holden           0
# Howard           0
# Jozy Altidore    8
# Onyewu           1
# Torres           1
# Name: shots, Length: 595, dtype: int64

# %%
df.shots == 0
# shots=0 ?
# Out:
# surname
# Abdoun            True
# Belhadj          False
# Boudebouz        False
# Bougherra        False
# Chaouchi          True
#                  ...
# Holden            True
# Howard            True
# Jozy Altidore    False
# Onyewu           False
# Torres           False
# Name: shots, Length: 595, dtype: bool

# %%
df.loc[df.shots >= 20, :]
# Out:
#               team position  minutes  shots  passes  tackles  saves  \
# surname
# Messi    Argentina  forward      450     21     321       10      0
# Gyan         Ghana  forward      501     27     151        1      0
# Villa        Spain  forward      529     22     169        2      0
#
#          Unnamed: 8  Unnamed: 9  Unnamed: 10  ...  Unnamed: 16  Unnamed: 17  \
# surname                                       ...
# Messi           NaN         NaN          NaN  ...          NaN          NaN
# Gyan            NaN         NaN          NaN  ...          NaN          NaN
# Villa           NaN         NaN          NaN  ...          NaN          NaN
#
#          Unnamed: 18  Unnamed: 19  Unnamed: 20  Unnamed: 21  Unnamed: 22  \
# surname
# Messi            NaN          NaN          NaN          NaN          NaN
# Gyan             NaN          NaN          NaN          NaN          NaN
# Villa            NaN          NaN          NaN          NaN          NaN
#
# ...

# %%
df[df.team == 'USA'] # shortcut filtering
# choose team=USA
# Out:
#               team    position  minutes  shots  passes  tackles  saves  \
# surname
# Beasley        USA  midfielder       10      0       4        0      0
# Bocanegra      USA    defender      390      1     130        9      0
# Bornstein      USA    defender      200      2      72        5      0
# Bradley        USA  midfielder      390      6     210        9      0
# Buddle         USA     forward       39      1      12        0      0
# Cherundolo     USA    defender      390      1     180       10      0
# Clark          USA  midfielder      121      0      42        4      0
# Demerit        USA    defender      390      2     129        7      0
# Dempsey        USA  midfielder      390     15     137        6      0
# Donovan        USA     forward      390      7     165        9      0
# Edu            USA  midfielder      198      2     116        4      0
# Feilhaber      USA  midfielder      165      3      71        5      0
# ...

# %%
df.loc[df.index == 'Torres', : ] # filter by index
# Out:
#              team    position  minutes  shots  passes  tackles  saves  \
# surname
# Torres   Paraguay    defender       82      2      29        1      0
# Torres      Spain     forward      278      9      50        0      0
# Torres        USA  midfielder       45      1      32        0      0
#
#          Unnamed: 8  Unnamed: 9  Unnamed: 10  ...  Unnamed: 16  Unnamed: 17  \
# surname                                       ...
# Torres          NaN         NaN          NaN  ...          NaN          NaN
# Torres          NaN         NaN          NaN  ...          NaN          NaN
# Torres          NaN         NaN          NaN  ...          NaN          NaN
#
#          Unnamed: 18  Unnamed: 19  Unnamed: 20  Unnamed: 21  Unnamed: 22  \
# surname
# Torres           NaN          NaN          NaN          NaN          NaN
# Torres           NaN          NaN          NaN          NaN          NaN
# Torres           NaN          NaN          NaN          NaN          NaN
#
# ...

# %%
df.loc[(df.team == 'Algeria') & (df.passes >= 150), :]
# Out:
#             team    position  minutes  shots  passes  tackles  saves  \
# surname
# Lacen    Algeria  midfielder      270      0     158        8      0
#
#          Unnamed: 8  Unnamed: 9  Unnamed: 10  ...  Unnamed: 16  Unnamed: 17  \
# surname                                       ...
# Lacen           NaN         NaN          NaN  ...          NaN          NaN
#
#          Unnamed: 18  Unnamed: 19  Unnamed: 20  Unnamed: 21  Unnamed: 22  \
# surname
# Lacen            NaN          NaN          NaN          NaN          NaN
#
#          Unnamed: 23  Unnamed: 24  Unnamed: 25
# surname
# Lacen            NaN          NaN          NaN
#
# [1 rows x 25 columns]

# %%
df.loc[df.team.str.endswith('land'), : ]
# Out:
#                         team    position  minutes  shots  passes  tackles  \
# surname
# Ashley Cole          England    defender      360      0     142       12
# Barry                England  midfielder      264      2     171        8
# Carragher            England    defender      135      0      74        4
# Crouch               England     forward       17      1       7        0
# Defoe                England     forward      173      5      17        1
# Gerrard              England  midfielder      360     10     227        5
# Glen Johnson         England    defender      357      3     173       17
# Green                England  goalkeeper       90      0      21        0
# Heskey               England     forward      176      2      53        7
# James                England  goalkeeper      270      0      72        0
# Joe Cole             England  midfielder       44      1      26        0
# ...

# %%
df.loc[df.index.str.contains('ve'), : ]
# Out:
#                       team    position  minutes  shots  passes  tackles  \
# surname
# Tevez            Argentina     forward      324      6     164        7
# Daniel Alves        Brazil    defender      310     11     215        6
# Chavez            Honduras    defender      270      0      62        3
# Riveros           Paraguay  midfielder      480      5     236       22
# Bruno Alves       Portugal    defender      360      1     166        5
# Nomvete       South Africa     forward       22      0       5        1
#
#               saves  Unnamed: 8  Unnamed: 9  Unnamed: 10  ...  Unnamed: 16  \
# surname                                                   ...
# Tevez             0         NaN         NaN          NaN  ...          NaN
# Daniel Alves      0         NaN         NaN          NaN  ...          NaN
# Chavez            0         NaN         NaN          NaN  ...          NaN
# Riveros           0         NaN         NaN          NaN  ...          NaN
# ...

# %%
df.query('team == "Spain" and passes >= 300')
# Out:
#             team    position  minutes  shots  passes  tackles  saves  \
# surname
# Alonso     Spain  midfielder      506      9     465       18      0
# Busquets   Spain  midfielder      511      0     466       15      0
# Capdevila  Spain    defender      540      1     310       10      0
# Pique      Spain    defender      540      2     402       15      0
# Xavi       Spain  midfielder      515      4     563        6      0
#
#            Unnamed: 8  Unnamed: 9  Unnamed: 10  ...  Unnamed: 16  Unnamed: 17  \
# surname                                         ...
# Alonso            NaN         NaN          NaN  ...          NaN          NaN
# Busquets          NaN         NaN          NaN  ...          NaN          NaN
# Capdevila         NaN         NaN          NaN  ...          NaN          NaN
# Pique             NaN         NaN          NaN  ...          NaN          NaN
# Xavi              NaN         NaN          NaN  ...          NaN          NaN
#
# ...

# %% [markdown]
# # Sorting

# %%
df.sort_values('passes', ascending=False)
#ascending=True เรียงจากน้อยไปมาก, ascending=False เรียงจากมากไปน้อย
# Out:
#                         team    position  minutes  shots  passes  tackles  \
# surname
# Xavi                   Spain  midfielder      515      4     563        6
# Busquets               Spain  midfielder      511      0     466       15
# Alonso                 Spain  midfielder      506      9     465       18
# Schweinsteiger       Germany  midfielder      531      5     423       23
# Pique                  Spain    defender      540      2     402       15
# ...                      ...         ...      ...    ...     ...      ...
# Eggimann         Switzerland    defender        1      0       0        0
# Barron           New Zealand  midfielder        1      0       0        0
# Konno                  Japan    defender        2      0       0        0
# Lee Seung-Yeoul  South Korea     forward        3      0       0        0
# Kim Dong-Jin     South Korea    defender        1      0       0        0
#
# ...

# %%
df.sort_values('team', ascending=False)
# Out:
#               team    position  minutes  shots  passes  tackles  saves  \
# surname
# Fernandez  Uruguay     forward        7      0       5        0      0
# Goduen     Uruguay    defender      315      1     120        9      0
# Suarez     Uruguay     forward      452     19     127        4      0
# Scotti     Uruguay    defender       95      0      22        5      0
# Perez      Uruguay  midfielder      567      2     252       34      0
# ...            ...         ...      ...    ...     ...      ...    ...
# Saifi      Algeria     forward       15      1       3        0      0
# Yahia      Algeria    defender      269      1      79        4      0
# Yebda      Algeria  midfielder      269      8     138       10      0
# Ziani      Algeria  midfielder      240      5      93        6      0
# Abdoun     Algeria  midfielder       16      0       6        0      0
#
#            Unnamed: 8  Unnamed: 9  Unnamed: 10  ...  Unnamed: 16  Unnamed: 17  \
# ...

# %%
df.sort_values(['team','passes'], ascending=[True,False]).tail(20)
# or use iloc[:20] to show 20 rows, or you can also use head(20), tail(20)
# Out:
#                    team    position  minutes  shots  passes  tackles  saves  \
# surname
# Forlan          Uruguay     forward      564     18     202        0      0
# Arevalo Rios    Uruguay  midfielder      570      5     195       21      0
# Maxi Pereira    Uruguay  midfielder      570      5     182       15      0
# Cavani          Uruguay     forward      435      9     151       11      0
# Victorino       Uruguay    defender      435      0     141        7      0
# Alvaro Pereira  Uruguay  midfielder      409      6     140       17      0
# Suarez          Uruguay     forward      452     19     127        4      0
# Goduen          Uruguay    defender      315      1     120        9      0
# Fucile          Uruguay    defender      371      2     115       14      0
# Muslera         Uruguay  goalkeeper      570      0      75        0     16
# Lugano          Uruguay    defender      398      2      67        6      0
# ...

# %%
df.sort_index(ascending=True) # sort index
# Out:
#                         team    position  minutes  shots  passes  tackles  \
# surname
# Abdoun               Algeria  midfielder       16      0       6        0
# Abe                    Japan  midfielder      351      0     101       14
# Abidal                France    defender      180      0      91        6
# Abou Diaby            France  midfielder      270      1     111        5
# Aboubakar           Cameroon     forward       46      2      16        0
# ...                      ...         ...      ...    ...     ...      ...
# de Zeeuw         Netherlands  midfielder       47      0      37        2
# van Bommel       Netherlands  midfielder      540      2     307       31
# van Bronckhorst  Netherlands    defender      540      1     271       10
# van Persie       Netherlands     forward      479     14     108        1
# von Bergen       Switzerland    defender      234      0      79        3
#
# ...

# %%
df.reset_index().sort_values(['team','surname'], ascending=[True,False])
# reset df
# Out:
#             surname     team    position  minutes  shots  passes  tackles  \
# 17            Ziani  Algeria  midfielder      240      5      93        6
# 16            Yebda  Algeria  midfielder      269      8     138       10
# 15            Yahia  Algeria    defender      269      1      79        4
# 14            Saifi  Algeria     forward       15      1       3        0
# 13           Mesbah  Algeria  midfielder        1      0       1        0
# ..              ...      ...         ...      ...    ...     ...      ...
# 557          Cavani  Uruguay     forward      435      9     151       11
# 558         Caceres  Uruguay    defender       90      0      32        4
# 556    Arevalo Rios  Uruguay  midfielder      570      5     195       21
# 575  Alvaro Pereira  Uruguay  midfielder      409      6     140       17
# 555           Abreu  Uruguay     forward       72      0      15        0
#
#      saves  Unnamed: 8  Unnamed: 9  ...  Unnamed: 16  Unnamed: 17  \
# ...

# %% [markdown]
# # Data entry

# %%
df_edit = df.copy()

# %%
df_edit.loc['Abdoun', 'shots'] = 1
# replace row 'Abdoun' column 'shots' with 1
df_edit.head(3)
# Out:
#               team    position  minutes  shots  passes  tackles  saves  \
# surname
# Abdoun     Algeria  midfielder       16      1       6        0      0
# Belhadj    Algeria    defender      270      1     146        8      0
# Boudebouz  Algeria  midfielder       74      3      28        1      0
#
#            Unnamed: 8  Unnamed: 9  Unnamed: 10  ...  Unnamed: 16  Unnamed: 17  \
# surname                                         ...
# Abdoun            NaN         NaN          NaN  ...          NaN          NaN
# Belhadj           NaN         NaN          NaN  ...          NaN          NaN
# Boudebouz         NaN         NaN          NaN  ...          NaN          NaN
#
#            Unnamed: 18  Unnamed: 19  Unnamed: 20  Unnamed: 21  Unnamed: 22  \
# surname
# Abdoun             NaN          NaN          NaN          NaN          NaN
# Belhadj            NaN          NaN          NaN          NaN          NaN
# ...

# %%
df_edit.loc[df_edit.shots==0, 'shots']
# Out:
# surname
# Chaouchi     0
# Guedioura    0
# Kadir        0
# Lacen        0
# M'Bolhi      0
#             ..
# Victorino    0
# Beasley      0
# Clark        0
# Holden       0
# Howard       0
# Name: shots, Length: 205, dtype: int64

# %%
df_edit.loc[df_edit.shots==0, 'shots'] = 1
# replace 0 with 1 in the shots column
df_edit.head(10)
# Out:
#               team    position  minutes  shots  passes  tackles  saves  \
# surname
# Abdoun     Algeria  midfielder       16      1       6        0      0
# Belhadj    Algeria    defender      270      1     146        8      0
# Boudebouz  Algeria  midfielder       74      3      28        1      0
# Bougherra  Algeria    defender      270      1      89       11      0
# Chaouchi   Algeria  goalkeeper       90      1      17        0      2
# Djebbour   Algeria     forward      123      3      19        1      0
# Ghezzal    Algeria     forward       40      3       8        0      0
# Guedioura  Algeria  midfielder       38      1      18        1      0
# Halliche   Algeria    defender      270      2      94        4      0
# Kadir      Algeria  midfielder      262      1     104        3      0
#
#            Unnamed: 8  Unnamed: 9  Unnamed: 10  ...  Unnamed: 16  Unnamed: 17  \
# surname                                         ...
# ...

# %% [markdown]
# # Calculate new column

# %%
df.minutes / 60
# Out:
# surname
# Abdoun           0.266667
# Belhadj          4.500000
# Boudebouz        1.233333
# Bougherra        4.500000
# Chaouchi         1.500000
#                    ...
# Holden           0.066667
# Howard           6.500000
# Jozy Altidore    5.933333
# Onyewu           2.833333
# Torres           0.750000
# Name: minutes, Length: 595, dtype: float64

# %%
df['hours_played'] = df.minutes/60
df
# Out:
#                   team    position  minutes  shots  passes  tackles  saves  \
# surname
# Abdoun         Algeria  midfielder       16      0       6        0      0
# Belhadj        Algeria    defender      270      1     146        8      0
# Boudebouz      Algeria  midfielder       74      3      28        1      0
# Bougherra      Algeria    defender      270      1      89       11      0
# Chaouchi       Algeria  goalkeeper       90      0      17        0      2
# ...                ...         ...      ...    ...     ...      ...    ...
# Holden             USA  midfielder        4      0       2        0      0
# Howard             USA  goalkeeper      390      0      81        0     14
# Jozy Altidore      USA     forward      356      8      84        2      0
# Onyewu             USA    defender      170      1      69        2      0
# Torres             USA  midfielder       45      1      32        0      0
#
# ...

# %%
df['pass_per_min'] = df.passes/df.minutes
df
# Out:
#                   team    position  minutes  shots  passes  tackles  saves  \
# surname
# Abdoun         Algeria  midfielder       16      0       6        0      0
# Belhadj        Algeria    defender      270      1     146        8      0
# Boudebouz      Algeria  midfielder       74      3      28        1      0
# Bougherra      Algeria    defender      270      1      89       11      0
# Chaouchi       Algeria  goalkeeper       90      0      17        0      2
# ...                ...         ...      ...    ...     ...      ...    ...
# Holden             USA  midfielder        4      0       2        0      0
# Howard             USA  goalkeeper      390      0      81        0     14
# Jozy Altidore      USA     forward      356      8      84        2      0
# Onyewu             USA    defender      170      1      69        2      0
# Torres             USA  midfielder       45      1      32        0      0
#
# ...

# %%
df.sort_values('pass_per_min', ascending=False)
# Out:
#                         team    position  minutes  shots  passes  tackles  \
# surname
# Sapara              Slovakia  midfielder        2      0       5        0
# Inamoto                Japan  midfielder        3      0       5        0
# Amorim              Portugal  midfielder        5      1       7        0
# Veron              Argentina  midfielder      185      3     235       10
# Fabregas               Spain  midfielder       94      1     116        2
# ...                      ...         ...      ...    ...     ...      ...
# Kim Dong-Jin     South Korea    defender        1      0       0        0
# Lee Seung-Yeoul  South Korea     forward        3      0       0        0
# Barron           New Zealand  midfielder        1      0       0        0
# Konno                  Japan    defender        2      0       0        0
# Eggimann         Switzerland    defender        1      0       0        0
#
# ...

# %%
df.minutes+df['Unnamed: 8']
# Out:
# surname
# Abdoun          NaN
# Belhadj         NaN
# Boudebouz       NaN
# Bougherra       NaN
# Chaouchi        NaN
#                  ..
# Holden          NaN
# Howard          NaN
# Jozy Altidore   NaN
# Onyewu          NaN
# Torres          NaN
# Length: 595, dtype: float64

# %%
df.minutes.add(df['Unnamed: 8'], fill_value=0)
# Out:
# surname
# Abdoun            16.0
# Belhadj          270.0
# Boudebouz         74.0
# Bougherra        270.0
# Chaouchi          90.0
#                  ...
# Holden             4.0
# Howard           390.0
# Jozy Altidore    356.0
# Onyewu           170.0
# Torres            45.0
# Length: 595, dtype: float64

# %%
# help(df.minutes.add)

# %% [markdown]
# # methods for column/df calcultaion

# %%
df.sum()
# search 'pandas api'
# Out:
# team            AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# position        midfielderdefendermidfielderdefendergoalkeeper...
# minutes                                                    124274
# shots                                                        1371
# passes                                                      50290
# tackles                                                      2494
# saves                                                         397
# Unnamed: 8                                                    0.0
# Unnamed: 9                                                    0.0
# Unnamed: 10                                                   0.0
# Unnamed: 11                                                   0.0
# Unnamed: 12                                                   0.0
# Unnamed: 13                                                   0.0
# Unnamed: 14                                                   0.0
# ...

# %%
df.shots.sum()
# Out:
# 1371

# %%
df.loc[:,'minutes':'saves'].sum(axis=1)
# Out:
# surname
# Abdoun            22
# Belhadj          425
# Boudebouz        106
# Bougherra        371
# Chaouchi         109
#                 ...
# Holden             6
# Howard           485
# Jozy Altidore    450
# Onyewu           242
# Torres            78
# Length: 595, dtype: int64
